# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot([.21,.21,.21,.21,.21,.21,.21,.21,.21,.21,.21], [6.4E-7, 6.6E-6, 1.1E-5, 2.5E-5,9.5E-5,1.2E-4,2.4E-4,3.9E-4,9.5E-4,3.3E-3,6.6E-3], 'o', label='Rowlinson et al (2015)')
plt.plot([22.9,4.1],[4.1E-7,1.4E-5],'rs',label='Stewart et al (2015)') #Stewart
plt.plot([1440],[1.9E-12],'g^', label='Obenberger et al (2015)') #Obenberger
plt.plot([5.5],[7.5E-5],'co', label='Bell et al (2014)') #Bell
plt.plot([.5],[1E-4],'ms', label='Carbone et al (2014)') #Carbone
plt.plot([.5],[2.2E-3],'ks', label='Cendes et al (2014)') #Cendes
plt.plot([.0021],[1.2E-3],'yo', label='Jaeger et al (2012)') #Jaeger
plt.plot([100],[9.55E-9],'y*', label= 'AARTFAAC!') #AARTFAAC6
plt.plot([100,100,100],[3.22E-9,4.6E-10,1.15E-10],'w*')
plt.ylabel('Surface Density (deg^-2)')
plt.xlabel('Sensitivity (Jy)')
plt.xscale('log')
plt.yscale('log')
#plt.show()

# %%
plt.plot([3600,86400,604800,2419200],[5.412E-8,2.26E-9,3.22E-10,8.06E-11],'o',label='Full Time')
plt.plot([3600,86400,604800,2419200],[7.73E-8,3.22E-9,4.6E-10,1.15E-10],'ro',label='30% Lost to RFI')
plt.xscale('log')
plt.yscale('log')
plt.title('AARTFAAC Sensitivity For Observation Time')
plt.legend()
plt.ylabel('Surface Density (deg^-2)')
plt.xlabel('Number of Images/ Number of Seconds')
